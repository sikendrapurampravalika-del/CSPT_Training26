# %% [markdown]
# <a href="https://colab.research.google.com/github/sikendrapurampravalika-del/CSPT_Training26/blob/main/linearequation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter a: "))
b = int(input("Enter b: "))
c = int(input("Enter c: "))

d = int(input("Enter d: "))
e = int(input("Enter e: "))
f = int(input("Enter f: "))

x = (c * e - b * f) / (a * e - b * d)
y = (a * f - c * d) / (a * e - b * d)

print("x =", x)
print("y =", y)
# Out:
# Enter a: 4
# Enter b: 6
# Enter c: 8
# Enter d: 10
# Enter e: 12
# Enter f: 14
# x = -1.0
# y = 2.0
